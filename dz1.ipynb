# %% [markdown]
# Курс "Методы сбора и обработки данных из сети Интернет"
# Домашнее задание №1.

# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests

req = requests.get('https://api.github.com/users/MarinaMedvedeva/repos')
repos = req.json()
print (repos)
# Out:
# [{'id': 591799567, 'node_id': 'R_kgDOI0YlDw', 'name': 'MSD_Internet', 'full_name': 'MarinaMedvedeva/MSD_Internet', 'private': False, 'owner': {'login': 'MarinaMedvedeva', 'id': 80186003, 'node_id': 'MDQ6VXNlcjgwMTg2MDAz', 'avatar_url': 'https://avatars.githubusercontent.com/u/80186003?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarinaMedvedeva', 'html_url': 'https://github.com/MarinaMedvedeva', 'followers_url': 'https://api.github.com/users/MarinaMedvedeva/followers', 'following_url': 'https://api.github.com/users/MarinaMedvedeva/following{/other_user}', 'gists_url': 'https://api.github.com/users/MarinaMedvedeva/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MarinaMedvedeva/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MarinaMedvedeva/subscriptions', 'organizations_url': 'https://api.github.com/users/MarinaMedvedeva/orgs', 'repos_url': 'https://api.github.com/users/MarinaMedvedeva/repos', 'events_url': 'https://api.github.com/users/MarinaMedvedeva/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MarinaMedvedeva/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/MarinaMedvedeva/MSD_Internet', 'description': 'Методы сбора и обработки данных из сети Интернет', 'fork': False, 'url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet', 'forks_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/forks', 'keys_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/teams', 'hooks_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/hooks', 'issue_events_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/issues/events{/number}', 'events_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/events', 'assignees_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/assignees{/user}', 'branches_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/branches{/branch}', 'tags_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/tags', 'blobs_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/languages', 'stargazers_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/stargazers', 'contributors_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/contributors', 'subscribers_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/subscribers', 'subscription_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/subscription', 'commits_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/contents/{+path}', 'compare_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/merges', 'archive_url': 'https://api.github.com/repos/MarinaMedvedeva/MSD_Internet/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos ...

# %%
for rep in repos:    
    print(rep['name'])
# Out:
# MSD_Internet
# Python-Libraries-Data-Science
# PythonFoundations
